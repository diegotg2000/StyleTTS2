# %%
import pandas as pd

# %%
df = pd.read_csv('/home/diego/Desktop/Master/M2/Internship/StyleTTS2/Data/train_list.txt', sep="|", header=None)

# %%
df.columns = ['audio', 'phonemes', 'x']

# %%
df['x'].value_counts()
# Out:
# x
# 0    12500
# Name: count, dtype: int64
